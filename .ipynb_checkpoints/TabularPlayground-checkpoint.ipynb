# %%
import pandas as pd
import numpy as np
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#        row_id        date  country       store         product  num_sold
# 0           0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...         ...      ...         ...             ...       ...
# 26293   26293  2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294  2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295  2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296  2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297  2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %%
df_test = pd.read_csv('test.csv')
df_test
# Out:
#       row_id        date  country       store         product
# 0      26298  2019-01-01  Finland  KaggleMart      Kaggle Mug
# 1      26299  2019-01-01  Finland  KaggleMart      Kaggle Hat
# 2      26300  2019-01-01  Finland  KaggleMart  Kaggle Sticker
# 3      26301  2019-01-01  Finland  KaggleRama      Kaggle Mug
# 4      26302  2019-01-01  Finland  KaggleRama      Kaggle Hat
# ...      ...         ...      ...         ...             ...
# 6565   32863  2019-12-31   Sweden  KaggleMart      Kaggle Hat
# 6566   32864  2019-12-31   Sweden  KaggleMart  Kaggle Sticker
# 6567   32865  2019-12-31   Sweden  KaggleRama      Kaggle Mug
# 6568   32866  2019-12-31   Sweden  KaggleRama      Kaggle Hat
# 6569   32867  2019-12-31   Sweden  KaggleRama  Kaggle Sticker
#
# [6570 rows x 5 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26298 entries, 0 to 26297
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    26298 non-null  int64
#  1   date      26298 non-null  object
#  2   country   26298 non-null  object
#  3   store     26298 non-null  object
#  4   product   26298 non-null  object
#  5   num_sold  26298 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 1.2+ MB

# %%
df_train.isnull().sum()
# Out:
# row_id      0
# date        0
# country     0
# store       0
# product     0
# num_sold    0
# dtype: int64

# %%
df_train['country'].value_counts()
# Out:
# Finland    8766
# Norway     8766
# Sweden     8766
# Name: country, dtype: int64

# %%
df_train['store'].value_counts()
# Out:
# KaggleMart    13149
# KaggleRama    13149
# Name: store, dtype: int64

# %%
df_train['product'].value_counts()
# Out:
# Kaggle Mug        8766
# Kaggle Hat        8766
# Kaggle Sticker    8766
# Name: product, dtype: int64

# %%
df_train['date'].value_counts()
# Out:
# 2015-01-01    18
# 2017-09-09    18
# 2017-09-07    18
# 2017-09-06    18
# 2017-09-05    18
#               ..
# 2016-04-30    18
# 2016-04-29    18
# 2016-04-28    18
# 2016-04-27    18
# 2018-12-31    18
# Name: date, Length: 1461, dtype: int64

# %%
def smape(target, predicted):
    return 100/len(target) * np.sum(2 * np.abs(predicted - target) / (np.abs(target) + np.abs(predicted)))

# %%
df_gdp = pd.read_csv('GDP_data_2015_to_2019_Finland_Norway_Sweden.csv', index_col='year')
df_gdp
# Out:
#       GDP_Finland  GDP_Norway  GDP_Sweden
# year
# 2015      234.440     385.802     505.104
# 2016      240.608     368.827     515.655
# 2017      255.017     398.394     541.019
# 2018      275.580     437.000     555.455
# 2019      268.782     405.510     533.880

# %%
def prepare_data(data):
    
    data['date'] = pd.to_datetime(data['date'])
    data['day'] = data['date'].dt.day
    data['day_of_week'] = data['date'].dt.day_of_week
    data['month'] = data['date'].dt.month
    data['year'] = data['date'].dt.year
    data['dayofyear'] = data['date'].dt.dayofyear
    data.loc[(data['year'] != 2016) & (data['month'] >= 3), 'dayofyear'] += 1
    
    data['gdp'] = 0.0
    for year in data['year'].unique():
        for country in data['country'].unique():
            data.loc[(data['year'] == year) & (data['country'] == country), 'gdp'] = \
                         df_gdp.loc[year, f'GDP_{country}']

    data['country'] = data['country'].factorize()[0]
    data['store'] = data['store'].factorize()[0]
    data['product'] = data['product'].factorize()[0]
    
    if 'num_sold' in data.columns:
        data['num_sold'] = np.log(data['num_sold'] / data['gdp'])

    return data

# %%
import dateutil.easter as easter

# I took this code from kaggle
def dates_shift(df):
    new_df = df.copy()
    # Easter
    easter_date = df.date.apply(lambda date: pd.Timestamp(easter.easter(date.year)))
    new_df['days_from_easter'] = (df.date - easter_date).dt.days.clip(-3, 59)
    new_df.loc[new_df['days_from_easter'].isin(range(12, 39)), 'days_from_easter'] = 12 # reduce overfitting
    
    # Last Wednesday of June
    wed_june_date = df.date.dt.year.map({2015: pd.Timestamp(('2015-06-24')),
                                         2016: pd.Timestamp(('2016-06-29')),
                                         2017: pd.Timestamp(('2017-06-28')),
                                         2018: pd.Timestamp(('2018-06-27')),
                                         2019: pd.Timestamp(('2019-06-26'))})
    new_df['days_from_wed_jun'] = (df.date - wed_june_date).dt.days.clip(-5, 5)
    
    # First Sunday of November (second Sunday is Father's Day)
    sun_nov_date = df.date.dt.year.map({2015: pd.Timestamp(('2015-11-1')),
                                         2016: pd.Timestamp(('2016-11-6')),
                                         2017: pd.Timestamp(('2017-11-5')),
                                         2018: pd.Timestamp(('2018-11-4')),
                                         2019: pd.Timestamp(('2019-11-3'))})
    new_df['days_from_sun_nov'] = (df.date - sun_nov_date).dt.days.clip(-1, 9)
    
    new_df = new_df.drop(['row_id', 'date'], axis=1)
    
    return new_df

# %%
submission = df_test[['row_id']]
df_train = prepare_data(df_train)
df_train = dates_shift(df_train)
df_test = prepare_data(df_test)
df_test = dates_shift(df_test)

# %%
df_train
# Out:
#        country  store  product  num_sold  day  day_of_week  month  year  \
# 0            0      0        0  0.338858    1            3      1  2015
# 1            0      0        1  0.796629    1            3      1  2015
# 2            0      0        2 -0.473593    1            3      1  2015
# 3            0      1        0  0.891939    1            3      1  2015
# 4            0      1        1  1.357343    1            3      1  2015
# ...        ...    ...      ...       ...  ...          ...    ...   ...
# 26293        2      0        1  0.393169   31            0     12  2018
# 26294        2      0        2 -0.798327   31            0     12  2018
# 26295        2      1        0  0.591960   31            0     12  2018
# 26296        2      1        1  0.953305   31            0     12  2018
# 26297        2      1        2 -0.358782   31            0     12  2018
#
#        dayofyear      gdp  days_from_easter  days_from_wed_jun  \
# 0              1  234.440                -3                 -5
# 1              1  234.440                -3                 -5
# 2              1  234.440                -3                 -5
# 3              1  234.440                -3                 -5
# 4              1  234.440                -3                 -5
# ...          ...      ...               ...                ...
# 26293        366  555.455                59                  5
# 26294        366  555.455                59                  5
# 26295        366  555.455                59                  5
# 26296        366  555.455                59                  5
# 26297        366  555.455                59                  5
#
#        days_from_sun_nov
# 0                     -1
# 1                     -1
# 2                     -1
# 3                     -1
# 4                     -1
# ...                  ...
# 26293                  9
# 26294                  9
# 26295                  9
# 26296                  9
# 26297                  9
#
# [26298 rows x 13 columns]

# %%
df_test
# Out:
#       country  store  product  day  day_of_week  month  year  dayofyear  \
# 0           0      0        0    1            1      1  2019          1
# 1           0      0        1    1            1      1  2019          1
# 2           0      0        2    1            1      1  2019          1
# 3           0      1        0    1            1      1  2019          1
# 4           0      1        1    1            1      1  2019          1
# ...       ...    ...      ...  ...          ...    ...   ...        ...
# 6565        2      0        1   31            1     12  2019        366
# 6566        2      0        2   31            1     12  2019        366
# 6567        2      1        0   31            1     12  2019        366
# 6568        2      1        1   31            1     12  2019        366
# 6569        2      1        2   31            1     12  2019        366
#
#           gdp  days_from_easter  days_from_wed_jun  days_from_sun_nov
# 0     268.782                -3                 -5                 -1
# 1     268.782                -3                 -5                 -1
# 2     268.782                -3                 -5                 -1
# 3     268.782                -3                 -5                 -1
# 4     268.782                -3                 -5                 -1
# ...       ...               ...                ...                ...
# 6565  533.880                59                  5                  9
# 6566  533.880                59                  5                  9
# 6567  533.880                59                  5                  9
# 6568  533.880                59                  5                  9
# 6569  533.880                59                  5                  9
#
# [6570 rows x 12 columns]

# %%
import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax, fig = plt.subplots(figsize=(16, 16))
sns.heatmap(df_train.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
def lgb_run(data):
    models = []
    full_preds = np.zeros(len(data))
    kfold = KFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('num_sold', axis=1), data['num_sold'])):
        x_train, y_train = data.loc[trn_ind].drop('num_sold', axis=1), data.loc[trn_ind, 'num_sold']
        x_val, y_val = data.loc[val_ind].drop('num_sold', axis=1), data.loc[val_ind, 'num_sold']

        model = LGBMRegressor()
        model.fit(x_train, y_train)
        predictions = model.predict(x_val)
        full_preds[y_val.index] = predictions
        models.append(model)
    full_preds = np.exp(full_preds) * data['gdp']
    print(f'MAPE: {mean_absolute_percentage_error(np.exp(data["num_sold"]) * data["gdp"], full_preds)}')
    print(f'SMAPE: {smape(np.exp(data["num_sold"]) * data["gdp"], full_preds)}')
    ax = lgb.plot_importance(models[-1], max_num_features=40, figsize=(15,15))
    plt.show()
    return models

# %%
models = lgb_run(df_train)
# Out:
# MAPE: 0.04363140241090379
# SMAPE: 4.3551198243597256

# %%
test_preds = np.zeros(len(df_test))
for model in models:
    test_preds = test_preds + np.exp(model.predict(df_test)) * df_test['gdp']
test_preds /= len(models)
test_preds
# Out:
# 0        370.311898
# 1        580.818813
# 2        162.442931
# 3        649.345582
# 4       1016.607214
#            ...
# 6565     801.895437
# 6566     231.747607
# 6567     924.484642
# 6568    1350.061828
# 6569     390.383046
# Name: gdp, Length: 6570, dtype: float64

# %%
# This gave me 5.21837 private score and 324/1591 place
submission['num_sold'] = np.round(test_preds)
submission.to_csv('submission.csv', index=False)
# Out:
# /tmp/ipykernel_6741/2844216624.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['num_sold'] = test_preds

# %%
preds = np.zeros(len(df_train))
for model in models:
    preds += np.exp(model.predict(df_train.drop('num_sold', axis=1))) * df_train['gdp']
preds /= len(models)
preds
# Out:
# 0         313.854328
# 1         490.941950
# 2         138.686660
# 3         557.941552
# 4         873.768663
#             ...
# 26293     832.505766
# 26294     240.583786
# 26295     959.312983
# 26296    1400.223723
# 26297     405.110797
# Name: gdp, Length: 26298, dtype: float64

# %%
smape(np.exp(df_train['num_sold']) * df_train['gdp'], preds)
# Out:
# 4.1376097576329345
