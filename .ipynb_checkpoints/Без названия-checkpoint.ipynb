# %%
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')
df_train
# Out:
#        row_id        date  country       store         product  num_sold
# 0           0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...         ...      ...         ...             ...       ...
# 26293   26293  2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294  2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295  2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296  2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297  2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26298 entries, 0 to 26297
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    26298 non-null  int64
#  1   date      26298 non-null  object
#  2   country   26298 non-null  object
#  3   store     26298 non-null  object
#  4   product   26298 non-null  object
#  5   num_sold  26298 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 1.2+ MB

# %%
df_train.isnull().sum()
# Out:
# row_id      0
# date        0
# country     0
# store       0
# product     0
# num_sold    0
# dtype: int64

# %%
df_train['country'].value_counts()
# Out:
# Finland    8766
# Norway     8766
# Sweden     8766
# Name: country, dtype: int64

# %%
df_train['store'].value_counts()
# Out:
# KaggleMart    13149
# KaggleRama    13149
# Name: store, dtype: int64

# %%
df_train['product'].value_counts()
# Out:
# Kaggle Mug        8766
# Kaggle Hat        8766
# Kaggle Sticker    8766
# Name: product, dtype: int64

# %%
df_train['date'].value_counts()
# Out:
# 2015-01-01    18
# 2017-09-09    18
# 2017-09-07    18
# 2017-09-06    18
# 2017-09-05    18
#               ..
# 2016-04-30    18
# 2016-04-29    18
# 2016-04-28    18
# 2016-04-27    18
# 2018-12-31    18
# Name: date, Length: 1461, dtype: int64

# %%
df_train['date'] = pd.to_datetime(df_train['date'])
df_train
# Out:
#        row_id       date  country       store         product  num_sold
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...        ...      ...         ...             ...       ...
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295 2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296 2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297 2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %%
df_train['day'] = df_train['date'].dt.day
df_train['day_of_week'] = df_train['date'].dt.day_of_week
df_train['month'] = df_train['date'].dt.month
df_train['year'] = df_train['date'].dt.year
df_train
# Out:
#        row_id       date  country       store         product  num_sold  day  \
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329    1
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520    1
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146    1
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572    1
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911    1
# ...       ...        ...      ...         ...             ...       ...  ...
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823   31
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250   31
# 26295   26295 2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004   31
# 26296   26296 2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441   31
# 26297   26297 2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388   31
#
#        day_of_week  month  year
# 0                3      1  2015
# 1                3      1  2015
# 2                3      1  2015
# 3                3      1  2015
# 4                3      1  2015
# ...            ...    ...   ...
# 26293            0     12  2018
# 26294            0     12  2018
# 26295            0     12  2018
# 26296            0     12  2018
# 26297            0     12  2018
#
# [26298 rows x 10 columns]

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

cal = calendar()
holidays = cal.holidays(start=df_train['date'].min(), end=df_train['date'].max())

df_train['holiday'] = df_train['date'].isin(holidays)
df_train
# Out:
#        row_id       date  country       store         product  num_sold  day  \
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329    1
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520    1
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146    1
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572    1
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911    1
# ...       ...        ...      ...         ...             ...       ...  ...
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823   31
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250   31
# 26295   26295 2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004   31
# 26296   26296 2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441   31
# 26297   26297 2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388   31
#
#        day_of_week  month  year  holiday
# 0                3      1  2015     True
# 1                3      1  2015     True
# 2                3      1  2015     True
# 3                3      1  2015     True
# 4                3      1  2015     True
# ...            ...    ...   ...      ...
# 26293            0     12  2018    False
# 26294            0     12  2018    False
# 26295            0     12  2018    False
# 26296            0     12  2018    False
# 26297            0     12  2018    False
#
# [26298 rows x 11 columns]

# %%
df_train = pd.concat([
    df_train.drop('country', axis=1),
    pd.get_dummies(df_train['country'], dtype=bool, prefix='country')
], axis=1)

df_train = pd.concat([
    df_train.drop('store', axis=1),
    pd.get_dummies(df_train['store'], dtype=bool, prefix='store')
], axis=1)

df_train = pd.concat([
    df_train.drop('product', axis=1),
    pd.get_dummies(df_train['product'], dtype=bool, prefix='product')
], axis=1)

df_train
# Out:
#        row_id       date  country       store         product  num_sold  day  \
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329    1
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520    1
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146    1
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572    1
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911    1
# ...       ...        ...      ...         ...             ...       ...  ...
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823   31
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250   31
# 26295   26295 2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004   31
# 26296   26296 2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441   31
# 26297   26297 2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388   31
#
#        day_of_week  month  year  holiday  country_Finland  country_Norway  \
# 0                3      1  2015     True             True           False
# 1                3      1  2015     True             True           False
# 2                3      1  2015     True             True           False
# 3                3      1  2015     True             True           False
# 4                3      1  2015     True             True           False
# ...            ...    ...   ...      ...              ...             ...
# 26293            0     12  2018    False            False           False
# 26294            0     12  2018    False            False           False
# 26295            0     12  2018    False            False           False
# 26296            0     12  2018    False            False           False
# 26297            0     12  2018    False            False           False
#
#        country_Sweden  store_KaggleMart  store_KaggleRama  product_Kaggle Hat  \
# 0               False              True             False               False
# 1               False              True             False                True
# 2               False              True             False               False
# 3               False             False              True               False
# 4               False             False              True                True
# ...               ...               ...               ...                 ...
# 26293            True              True             False                True
# 26294            True              True             False               False
# 26295            True             False              True               False
# 26296            True             False              True                True
# 26297            True             False              True               False
#
#        product_Kaggle Mug  product_Kaggle Sticker
# 0                    True                   False
# 1                   False                   False
# 2                   False                    True
# 3                    True                   False
# 4                   False                   False
# ...                   ...                     ...
# 26293               False                   False
# 26294               False                    True
# 26295                True                   False
# 26296               False                   False
# 26297               False                    True
#
# [26298 rows x 19 columns]

# %%
import lightgbm as lgb
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import KFold
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax, fig = plt.subplots(figsize=(15, 15))
sns.heatmap(df_train.drop('row_id', axis=1).corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
def smape(target, predicted):
    return 100/len(target) * np.sum(2 * np.abs(predicted - target) / (np.abs(target) + np.abs(predicted)))

# %%
def lgb_run(data):
    last_model = None
    full_preds = np.zeros(len(data))
    kfold = KFold(n_splits=5, random_state=0, shuffle=True)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(data.drop('num_sold', axis=1), data['num_sold'])):
        x_train, y_train = data.loc[trn_ind].drop('num_sold', axis=1), data.loc[trn_ind, 'num_sold']
        x_val, y_val = data.loc[val_ind].drop('num_sold', axis=1), data.loc[val_ind, 'num_sold']

        model = LGBMRegressor()
        model.fit(x_train, y_train)
        predictions = model.predict(x_val)
        full_preds[y_val.index] = predictions
        last_model = model
    print(f'MAPE: {mean_absolute_percentage_error(full_preds, data["num_sold"])}')
    print(f'SMAPE: {smape(full_preds, data["num_sold"])}')
    ax = lgb.plot_importance(last_model, max_num_features=40, figsize=(15,15))
    plt.show()

# %%
lgb_run(df_train.drop(['row_id', 'date'], axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14420/486829693.py in <module>
# ----> 1 lgb_run(df_train.drop(['row_id', 'date'], axis=1))
#
# /tmp/ipykernel_14420/2600590067.py in lgb_run(data)
#       8
#       9         model = LGBMRegressor()
# ---> 10         model.fit(x_train, y_train)
#      11         predictions = model.predict(x_val)
#      12         full_preds[y_val.index] = predictions
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     893             callbacks=None, init_model=None):
#     894         """Docstring is inherited from the LGBMModel."""
# --> 895         super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#     896                     eval_set=eval_set, eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     897                     eval_init_score=eval_init_score, eval_metric=eval_metric,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     746         callbacks.append(record_evaluation(evals_result))
#     747
# --> 748         self._Booster = train(
#     749             params=params,
#     750             train_set=train_set,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     270     # construct booster
#     271     try:
# --> 272         booster = Booster(params=params, train_set=train_set)
#     273         if is_valid_contain_train:
#     274             booster.set_train_data_name(train_data_name)
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2603                 )
#    2604             # construct booster object
# -> 2605             train_set.construct()
#    2606             # copy the parameters from train_set
#    2607             params.update(train_set.get_params())
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in construct(self)
#    1813             else:
#    1814                 # create train
# -> 1815                 self._lazy_init(self.data, label=self.label,
#    1816                                 weight=self.weight, group=self.group,
#    1817                                 init_score=self.init_score, predictor=self._predictor,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1472             self.pandas_categorical = reference.pandas_categorical
#    1473             categorical_feature = reference.categorical_feature
# -> 1474         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#    1475                                                                                              feature_name,
#    1476                                                                                              categorical_feature,
#
# ~/.local/lib/python3.8/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     592         if bad_indices:
#     593             bad_index_cols_str = ', '.join(data.columns[bad_indices])
# --> 594             raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
#     595                              "Did not expect the data types in the following fields: "
#     596                              f"{bad_index_cols_str}")
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: country, store, product
